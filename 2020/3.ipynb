# %%
with open("3.txt", "r") as f:
    lines = f.read().splitlines() 
lines
# Out:
# ['.##......#.##..#..#..##....#...',
#  '...##.....#...###........###...',
#  '#....##....#.....#.....#..##.##',
#  '.......#.###.#......#..#..#..#.',
#  '##..........#....#.#...#.......',
#  '###.#.#.#......##...#..........',
#  '.#.##........#..............#..',
#  '..#..........#...##..#.......##',
#  '.........##...#...#....###.#...',
#  '#.......#.....#.#.#...###.##.#.',
#  '...#...#...#......#........#.##',
#  '....#..........#.....#..#....##',
#  '.#.#.##....#.#...#.............',
#  '#....#..#.....#.#..............',
#  '........#....#....#..#........#',
#  '..#.......#...#....##.#........',
#  '......#.........##.......#.#...',
#  '............#.......#..........',
#  '.....#..#.#..#........##...#...',
#  '....#.....................###..',
#  '..#.......#.........#..##....##',
#  '..#........#..#...#........#...',
#  '..............#....##..##....#.',
#  '....#..#.#.......#....#..#...##',
#  '.#........##......#.#..#.#.....',
#  '............#.##...##...#...##.',
# ...

# %%
hits = 0
misses = 0
x = 0
y = 0
xMax = len(lines[0])
yMax = len(lines)

while True:
    x = (x + 3) % xMax
    y = y + 1

    if y >= yMax:
        break

    if lines[y][x] == '#':
        hits += 1
    
print(f'Result: {hits}')
# Out:
# Result: 34

# %%
# 1-1 61
# 3-1 265
# 5-1 82
# 7-1 70
# 1-2 34
print(61*265*82*70*34)
# Out:
# 3154761400
