# %%
import string

# %%
f = open("2.txt", "r")
lines = f.readlines()
f.close()
lines
# Out:
# m\n',
#  '5-7 p: gzlqbpkl\n',
#  '6-7 w: qwwgdwwcw\n',
#  '2-3 x: qxxtfnxx\n',
#  '3-5 n: nnvnrn\n',
#  '4-5 l: lllndx\n',
#  '6-8 c: hjrcccccdvcst\n',
#  '8-16 w: ftwmgvxwcnbnhnxlvdfl\n',
#  '4-15 d: jldsrczptcggwvd\n',
#  '4-6 h: hhmhhh\n',
#  '2-6 j: jtnlnlg\n',
#  '14-18 q: qqqqqqqqqqqqqnqqqqq\n',
#  '5-6 p: xlhmshqtplxfzgpj\n',
#  '9-10 r: rrrtrrrrrrrr\n',
#  '1-5 p: shqhvbcnmphrdk\n',
#  '8-14 q: qqtqqdqqqqqqvxqq\n',
#  '4-9 c: zvdccctccc\n',
#  '6-7 n: lnfhdndhtnlnpnnf\n',
#  '15-16 c: rbcrqqcbmcddnpwc\n',
#  '4-7 s: mssssdst\n',
#  '5-9 l: qlgqlkftlkjb\n',
#  '8-11 j: jjjjzmkjljzwmjjqbjq\n',
#  '3-4 j: jfmr\n',
#  '2-5 r: rfrrq\n',
#  '1-4 m: msmmmc\n',
#  '3-4 j: vfjhvjqcjnzpl\n',
#  '2-4 c: cvcc\n',
#  '4-5 d: dddfgddd\n',
#  '2-5 z: dndsb\n',
#  '2-7 h: hhmqhthhhhl\n',
#  '11-15 l: llllkllllwlljllglpl\n',
#  '2-3 j: cjjjgjnp\n',
#  '15-16 g: gggggggggggvggxlg\n',
#  '7-8 p: pnppppjj\n',
#  '17-18 h: hhhhhhhhhhhhhhhhhh\n',
#  '2-3 f: frlf\n',
#  '5-6 v: vvvvvv\n',
#  '10-11 n: nnnnnngnnnnrnnndrv\n',
#  '4-8 f: jhqdjfnfft\n',
#  '14-15 l: llllqlllvllllllssl\n',
#  '5-6 w: wkjwgch\n',
#  '4-11 h: jxjhhhnhhhhhtch\n',
#  '10-11 m: mmmmmmmmmrrm\n',
#  '4-10 m: mwjtqmwgnq\n',
#  '16-17 v: lprvzvvvvvvvhvvmvvv\n',
#  '5-7 g: gggfggg\n',
#  '11-14 l: lllzllldplhdllll\n',
#  '3-13 s: qcvwtwstkvrrfzs\n',
#  '16-18 g: ggjgggcggggggggzglg\n',
#  '3-4 s: sscfs\n',
#  '11-13 c: cjcccfccscwcclcccb\n',
#  '6-8 k: zkkkklphkk\n',
#  '1-7 j: nkqkqbl\n',
#  '1-8 h: sshmwjhkkjfhgfhhd\n',
#  '4-5 v: rvvvvvvv\n',
#  '2-3 h: phhhb\n',
#  '13-14 j: prdbjqmvbmjspr\n',
#  '12-19 l: mllljlllllllllllllt\n',
#  '13-15 x: rgnqfdxsvlplxjx\n',
#  '7-10 r: rrrrrrrrrbr\n',
#  '1-4 b: bbbbmbb\n',
#  '8-9 f: gfndcxcvm\n',
#  '5-6 n: bnmnnnnxjfrn\n',
#  '4-5 n: nnnpxn\n',
#  '7-9 r: rgrrsrrrwrrr\n',
#  '1-6 p: mppxpp\n',
#  '4-5 k: nckkmkzkxg\n',
#  '1-4 s: sssssjsszssssssn\n',
#  '2-3 g: sxpw\n',
#  '2-5 r: rrmrcgrrrlrq\n',
#  '5-9 n: nkxnnnnrnp\n',
#  '14-15 b: bbbbbbbbpbbbbcmbb\n',
#  '1-4 c: rsrswbcf\n',
#  '3-4 g: ggxctzgs\n',
#  '5-6 p: ppppfp\n',
#  '5-7 s: sswssssqbs\n',
#  '5-11 z: zhvlzwfgpgzzzz\n',
#  '8-9 m: mmmmmmmml\n',
#  '13-14 s: sssssssssssssb\n',
#  '9-12 f: fhstmfffkmjrfffpr\n',
#  '3-4 z: zzzz\n',
#  '7-8 z: zzbzzzpwz\n',
#  '2-12 d: mdddcdsddddrdd\n',
#  '1-10 s: xhqvwjvbspskb\n',
#  '6-13 z: zzzzzzzzzzzzrzz\n',
#  '4-7 r: rwrrtrsrrpr\n',
#  '2-9 g: lgpkjldqwvhntvwgb\n',
#  '7-11 t: xdttntttvtzttzjf\n',
#  '8-15 v: cnvvjrzvvvvvprfrv\n',
#  '1-2 g: vggmh\n',
#  '11-13 t: tzzfrvhmtctttttthtnt\n',
#  '16-17 s: ssssssvsssssssssp\n',
#  '2-6 f: frfhfdf\n',
#  '6-8 h: jhhhhhwmh\n',
#  '7-8 n: rmnclfgn\n',
#  '10-11 m: mmmmmmmmmxn\n',
#  '9-13 h: hhhhhhhhhhhqhhhh\n',
#  '10-11 q: qqphmqqqlqq\n',
#  '10-18 q: qqqpcqgqqqqqqqqqdqqp\n',
#  '2-15 s: pqmfksdwbkklrlm\n',
#  '15-16 p: pppppppppppppprx\n',
#  '6-11 d: vddddswgdjz\n',
#  '2-8 m: mrmmpmms\n',
#  '7-8 x: xxxxxxxxx\n',
#  '3-6 g: bmgtgwjnrdq\n',
#  '1-11 j: jgjjjjpjjjjjjj\n',
#  '1-6 r: rqqvmrbrbrztwk\n',
#  '3-7 h: hhfhhhkwd\n',
#  '5-9 w: wwwwwwwwwwwww\n',
#  '11-12 g: gvvczkkmtsgtpsgbg\n',
#  '4-10 q: qqqqqqqqqqq\n',
#  '4-6 t: tttvtwqt\n',
#  '9-10 h: hhhhhhhhkw\n',
#  '8-12 s: cssssssfxssmsrwssssf\n',
#  '2-5 c: sgwzjggz\n',
#  '3-6 m: mmzmmz\n',
#  '10-13 v: mvvvvqdvvfhvfv\n',
#  '3-6 j: slvljjkbtjdqvq\n',
#  '2-6 s: sbsssgsfmsjssssssps\n',
#  '5-7 r: xcdwvgrrrprzflmrcv\n',
#  '4-6 l: bdbdvlllltlv\n',
#  '6-14 s: sxsssqsqsssvsssssss\n',
#  '10-12 j: jjkjljjjjzjlvmw\n',
#  '19-20 d: ddddxddddwddddddrjdd\n',
#  '3-5 x: mjxxk\n',
#  '9-10 c: ccvbcbcccccc\n',
#  '3-4 t: kpvn\n',
#  '5-6 v: qcgpvw\n',
#  '5-7 l: ljjllpklctzlv\n',
#  '6-14 h: dxhhgzhhtdhthrjqn\n',
#  '11-14 q: qqqqqqqqqqnqqzqq\n',
#  '1-8 p: pshzfpnpp\n',
#  '7-12 l: mwclllllflklhl\n',
#  '2-10 j: jmjgwjjjjjtfj\n',
#  '5-6 j: jjkmjmjbjj\n',
#  '4-14 f: ffbgdffrdffffh\n',
#  '5-10 t: tttnbtrhchdt\n',
#  '6-10 c: kccrcjcscmccct\n',
#  '10-18 c: cccvccccchccccccvqc\n',
#  '2-9 p: ppprplrrpp\n',
#  '11-12 x: xxxxxxxxxxxxt\n',
#  '17-18 w: wwtrwxwwwmwwwwwwww\n',
#  '6-7 r: rrrfrrzrrg\n',
#  '1-3 r: gflrrg\n',
#  '10-19 z: zqczjxrzrpzzzdfzgzd\n',
#  '4-6 n: nnnnnknnnnnnjnnnnn\n',
#  '7-9 n: nnnnnnnnw\n',
#  '4-9 k: qnvkkfphktkt\n',
#  '6-8 f: fffrftfpfffrfcfff\n',
#  '3-6 q: qqqqqvqqq\n',
#  '5-6 x: llxdwx\n',
#  '7-10 n: nnnnnnnnnnnnnnnn\n',
#  '12-15 j: jjjjjjvjjjjwjjv\n',
#  '6-9 f: dnjjlvkfrkf\n',
#  '11-17 h: hhhmhxnhhjvhhrwjmhh\n',
#  '9-16 f: fffffffffffffffff\n',
#  '3-4 q: qqqqk\n',
#  '6-8 b: gwxlbzzprtn\n',
#  '7-17 g: grqqztqvggjjgdggfgg\n',
#  '1-10 k: ksghkhvzkxjgxks\n',
#  '10-14 f: pbsffkfftfffff\n',
#  '1-6 n: bnnfnb\n',
#  '1-2 c: hdzqlbcnzjvs\n',
#  '1-19 z: zzvzzzzzzzzzzzzzzzz\n',
#  '8-12 m: vvmmbmmvkmmmm\n',
#  '2-9 t: ttwtxthgtptttttg\n',
#  '2-4 r: rlhvrrqjtswfsb\n',
#  '9-16 s: dssnssjftsssshsp\n',
#  '10-11 z: zzzzzzzzmhs\n',
#  '5-9 j: tjrgpjcjl\n',
#  '8-11 t: xtlntfwttnp\n',
#  '1-4 m: kcxbmdmmk\n',
#  '3-4 x: xxldxxnq\n',
#  '4-14 v: pvqkvbbvsjjxvtvvsrrv\n',
#  '4-7 v: bpwtsvm\n',
#  '10-12 j: jjjnjjjjjjjj\n',
#  '5-9 h: dmqpdshshh\n',
#  '9-11 h: prhhhhhhfvgh\n',
#  '2-4 d: qdddd\n',
#  '3-6 j: jjjjjjj\n',
#  '7-13 m: gjpmplmtmmhvm\n',
#  '6-7 x: xxxxpzw\n',
#  '6-9 k: kswkfhkzkkr\n',
#  '3-8 m: mxmdmqmxhsdrms\n',
#  '12-13 b: bbbrbbbbbbbbbbbbb\n',
#  '5-6 h: cphxvkmhghh\n',
#  '6-14 k: kksgdkvhwkkxbkcvb\n',
#  '4-5 z: zzzmg\n',
#  '9-13 l: lllllllllllll\n',
#  '17-19 b: pbbbbbbbbbbbkbbbbbpb\n',
#  '5-6 p: ppvqcqp\n',
#  '2-7 n: snlcnszdc\n',
#  '1-3 m: qmmz\n',
#  '4-6 w: wwwwwwww\n',
#  '6-8 f: mfffffff\n',
#  '1-8 l: lllllllrlllll\n',
#  '3-10 d: fmwvkqdhgh\n',
#  '3-8 v: vvvvzsvx\n',
#  '12-14 m: mpmmmmmmmmmdmnm\n',
#  '11-12 m: mpmmmmmmmmzwm\n',
#  '5-18 g: khsdgtssgvkwwnwhbg\n',
#  '15-16 q: sqtqlqqvqqqqqfqdw\n',
#  '3-7 p: pffbppdpnhqpzht\n',
#  '10-19 r: rrrrrrrrrlrrrrrrrrf\n',
#  '1-2 d: mfdrnswwhg\n',
#  '2-3 d: lcdd\n',
#  '13-14 k: kkkkskkkkkkkrm\n',
#  '1-4 j: jjdt\n',
#  '7-9 r: rrrrrrnrdrrrrr\n',
#  '1-14 v: vvhvvvvhvvvvvvkvnvvv\n',
#  '2-4 c: crsncccbwccvb\n',
#  '12-14 w: xwwwwwwwwwdfwjww\n',
#  '16-18 l: llllllldllllllldlfl\n',
#  '14-16 p: jpvhrsgpdhhqwpdp\n',
#  '9-10 m: bnfmvmmmmsmmmm\n',
#  '9-13 t: tpmsttfcctksdktdfqx\n',
#  '1-3 c: gzcvchdwdbq\n',
#  '2-3 v: xrvvvwn\n',
#  '1-4 b: bbbb\n',
#  '13-16 s: snsssssgssssjssjs\n',
#  '2-5 t: gwtcl\n',
#  '1-6 s: qsssmdsssm\n',
#  '7-14 z: bhgrzzjzgzmzzzzz\n',
#  '1-3 p: ppnptchxppvw\n',
#  '11-16 b: bbmbbbbdbbhjbbbvbjc\n',
#  '4-8 x: xzmkxrvxqxvt\n',
#  '1-2 m: mmmm\n',
#  '1-4 r: wrjb\n',
#  '7-11 d: dddddhdckbddc\n',
#  '4-5 w: wwwmw\n',
#  '10-12 p: pppppppgpppp\n',
#  '2-6 v: vtvvvrv\n',
#  '5-9 w: gwwwlwwjnw\n',
#  '8-11 j: jjjjjjdvjjcjjj\n',
#  '6-7 s: sssmsss\n',
#  '6-20 d: dsrnfpphdznqdjfbqvql\n',
#  '2-7 x: rlhprqxswxckpxh\n',
#  '3-4 q: qhqq\n',
#  '4-9 z: wzgzrzzzznzqrzvjvtn\n',
#  '6-8 d: cldrblzkmhmc\n',
#  '5-7 t: ttttjtht\n',
#  '3-10 l: lllhzklllllll\n',
#  '14-15 k: kkskkkkkkkkkkkkkkkkk\n',
#  '6-12 q: qqqqqgqqqqqr\n',
#  '12-15 f: fcffffffrfffffflmfw\n',
#  '5-7 l: nhltlhq\n',
#  '10-12 j: tjjfkbgjzcwsp\n',
#  '6-7 r: rrvrrmqr\n',
#  '9-11 m: mmmkmmggmfmhtmmrm\n',
#  '11-19 d: dkddrdddnddcdwdvldd\n',
#  '6-7 n: lnnnnfltcz\n',
#  '7-9 j: jjjgjjjjjj\n',
#  '11-14 m: mmmmmmmmmrmzmmmmmmmm\n',
#  '5-6 m: mdnxmmtmmjkmlzpzj\n',
#  '2-9 g: hgmjfsvdgkgsbr\n',
#  '5-6 t: sbttttkb\n',
#  '5-9 t: tnttwrhttt\n',
#  '3-18 t: fnwszlmqhlzdzhmkmt\n',
#  '3-4 b: bbmbbbzzbbbnbbx\n',
#  '8-16 l: vxlllllkllllllljl\n',
#  '5-13 m: xmxqfgjjtxrrfwpzjmjq\n',
#  '14-15 q: qqqqqqqqqfqqqfq\n',
#  '7-10 w: wwwwwwbwst\n',
#  '11-12 j: djjjjjjjwjsljj\n',
#  '2-9 j: pjjzxjlbjmjjjj\n',
#  '6-7 r: rrrrtrr\n',
#  '4-5 x: plnxmrxxxrkv\n',
#  '10-11 b: cbblcbbsmhnbbbbndb\n',
#  '1-6 v: vvxvvwv\n',
#  '8-12 t: ftttttltttttttttt\n',
#  '4-5 p: jzpjf\n',
#  '1-5 g: zbwrgrk\n',
#  '4-6 q: kzjnpf\n',
#  '5-7 b: gbbbbbbbbw\n',
#  '10-11 r: rprjzrrrrqm\n',
#  '18-19 k: xkkvkkkkzkdkzkkkkjtc\n',
#  '10-15 x: xxxxrxfxxxxxxhx\n',
#  '2-4 p: xqvp\n',
#  '13-14 t: tttntttttttttt\n',
#  '5-18 p: qpljzcpxppzhbqpprrjz\n',
#  '4-5 l: lllll\n',
#  '4-7 m: mmmmmpm\n',
#  '3-8 b: bbzbbbtglbb\n',
#  '1-4 l: lqlm\n',
#  '5-7 v: vxvvvpvvv\n',
#  '9-11 n: nnznhdrnbnxnnn\n',
#  '2-7 h: chdvhrh\n',
#  '4-7 v: twgvkvvfhzv\n',
#  '2-6 q: mqfqvq\n',
#  '10-11 j: jjjjjjjhjqldj\n',
#  '5-8 m: rvmpmggmhmpmmj\n',
#  '7-8 j: jjhjjjpj\n',
#  '12-13 z: zzzzzzzqzzzpz\n',
#  '5-12 p: qptzdzpsppppn\n',
#  '14-19 k: kkkkkkkkkkkkkgkkkkk\n',
#  '8-12 v: vvpdvfvvvvvttpcv\n',
#  '9-13 x: mxvxxxxxvxsxwxxxbj\n',
#  '6-15 w: fwrwqzwwtwwbwwg\n',
#  '4-5 t: tttttjtw\n',
#  '3-4 d: sddxfd\n',
#  '3-4 t: rjxwfzktkvszlhttjd\n',
#  '18-19 c: cckccqccfccnnjcczgrr\n',
#  '7-9 k: kkkkkkkklkk\n',
#  '4-5 v: dvvlsvjv\n',
#  '7-9 c: cccccrccccccccc\n',
#  '9-10 x: xxxwxxxxxx\n',
#  '1-4 k: kkhk\n',
#  '3-4 k: kjztk\n',
#  '1-5 m: bhcmm\n',
#  '2-4 f: ffff\n',
#  '8-14 s: sspsssttslsssslwss\n',
#  '3-4 k: qkjk\n',
#  '14-17 k: kxrmldkdcpnxckhfkwqz\n',
#  '4-5 q: qqqfngfqqq\n',
#  '1-3 b: nfstkpdbbdtbghdt\n',
#  '2-5 q: pqhrqqnfrskvzz\n',
#  '3-7 r: mhrwxrrrrskdjrb\n',
#  '2-8 w: wvffwwqkww\n',
#  '4-5 w: wwwwqww\n',
#  '5-11 h: cchhhrmjdkhqwchhbhz\n',
#  '3-6 z: nzzkgzp\n',
#  '5-7 l: cwllllltlllll\n',
#  '17-18 q: cmhblsqvqjqwqqvrwtqp\n',
#  '6-19 m: mmdmmlbmmmmmmmmmmmrm\n',
#  '17-20 b: bbbbbbbbbbbbbbbbsbbt\n',
#  '3-4 m: xmgj\n',
#  '9-14 r: qkktgxrsfxgknrj\n',
#  '2-4 s: khcjpl\n',
#  '4-17 w: nfwcmjnkczdxvsvzx\n',
#  '3-10 r: jrrggrwfrrrjrprrngtr\n',
#  '6-11 n: rpnnltfnxtj\n',
#  '12-16 q: qqqqqsvqqqqwqqqq\n',
#  '1-3 w: mdwd\n',
#  '8-9 j: jjjjjjjbj\n',
#  '9-17 k: mkkklkkkkvkkmpknvkk\n',
#  '4-5 g: htgghp\n',
#  '18-19 c: ccczcggccxccclcccgc\n',
#  '2-4 p: pfnp\n',
#  '3-4 w: vwfq\n',
#  '9-16 j: jjljjjjjvjjjjjjjjtj\n',
#  '12-17 v: vvcgvvvvvcvzvvsvlvv\n',
#  '2-11 t: xhqtmtwtttgtttthtt\n',
#  '3-4 h: hhswh\n',
#  '5-6 w: wwwwwww\n',
#  '5-9 c: ccscccckc\n',
#  '4-8 b: bbkgbbbgb\n',
#  '5-6 q: dkqrqp\n',
#  '11-12 t: ttttnttttpqdttg\n',
#  '3-6 h: hhfwhhd\n',
#  '12-13 r: rrrrrrrrrrrrrrrr\n',
#  '3-20 r: rrrrrrrrrrrrrrrrrrrr\n',
#  '4-5 c: ctcccqcwcc\n',
#  '4-11 l: llldwlvlmlqgl\n',
#  '6-7 t: ktbttkqtt\n',
#  '3-7 t: jmtvtrttcwf\n',
#  '2-8 d: bjdvqzbg\n',
#  '5-10 k: qqmkvkknxjmkckk\n',
#  '6-7 z: zzzzzzzl\n',
#  '2-12 p: wmtjnsxzgkkcwnwc\n',
#  '2-18 g: wvhbzrwgnlrrhnhcznv\n',
#  '4-8 q: mfqcdghqmxqzcljczqt\n',
#  '1-3 t: nktl\n',
#  '2-16 x: vxzczxqbgfgrcghx\n',
#  '15-16 j: vjtjjjnzjzfjjbcwdl\n',
#  '11-14 w: wwwwwwwwwwpwwww\n',
#  '2-11 m: mnmmmmmsmmnmmmm\n',
#  '2-3 l: llqglv\n',
#  '8-11 d: ddddddlmddgddddsdd\n',
#  '11-14 w: wwwwwwwwwlzwwhw\n',
#  '15-17 s: ssksssrsdssswpmdm\n',
#  '11-14 x: xxxxxxxxxhxxxxx\n',
#  '12-14 q: mqqqqfqqpqqqqqqqk\n',
#  '3-4 x: rxjx\n',
#  '7-14 w: wpwwwwwqgwwwwhsw\n',
#  '8-16 s: sssssssgssssssvcss\n',
#  '4-5 g: gxgggg\n',
#  '6-8 b: bbbbbdbxbbbbb\n',
#  '15-16 x: dfxxxxxxxxxqxxxxxrx\n',
#  '2-3 x: cxxnr\n',
#  '2-4 d: tdjdpzrrbpmmbdx\n',
#  '6-10 l: lllllllllllll\n',
#  '10-14 s: sssssssssmsssrss\n',
#  '1-4 c: ccdc\n',
#  '1-4 w: bxzwjqdwpwlwjn\n',
#  '2-5 l: vqllflll\n',
#  '10-17 z: zmjrzzzzzszzzslzzmzz\n',
#  '4-9 c: dcckccjpmcq\n',
#  '12-14 w: wwrwxwwwlwwwwwwww\n',
#  '1-4 s: kjsc\n',
#  '5-11 w: wlwwwwwwpwj\n',
#  '3-6 q: dpcqqfq\n',
#  '9-11 l: lllllrfnmnblfrll\n',
#  '5-8 r: rrrxhrrgr\n',
#  '3-13 h: hhhhhhhhhhhbhhchh\n',
#  '2-5 f: pffqfw\n',
#  '1-3 x: xxxx\n',
#  '2-4 g: rgpgtwwrfxdbgs\n',
#  '1-4 f: xffnf\n',
#  '7-19 k: kprtbkxkkkrkkkkkkdh\n',
#  '15-16 z: zzzzzzzzzzzzzzjmz\n',
#  '3-4 p: xppp\n',
#  '10-13 l: jlblmllgllgll\n',
#  '1-5 s: fsssx\n',
#  '3-6 d: dbjddt\n',
#  '9-10 s: ssssssssqs\n',
#  '1-7 s: szjnqdss\n',
#  '5-11 c: cccctsccccbcc\n',
#  '2-3 d: cbdhd\n',
#  '5-16 j: jjjjxjjjjjjqjjjjjj\n',
#  '9-17 g: gjgggglgxgggggggn\n',
#  '1-2 r: dhrmmccfnthtxmmxp\n',
#  '8-12 q: qqpqmqqzqbqqkn\n',
#  '5-13 q: qqqqwqqqqqfqqq\n',
#  '2-9 m: kzwvwzqrmvn\n',
#  '3-6 c: fscccgc\n',
#  '14-15 h: hhhhhhpbhhhhhhhhh\n',
#  '1-5 c: cxltc\n',
#  '4-5 d: dvddd\n',
#  '4-5 t: vfctz\n',
#  '3-4 r: rrlr\n',
#  '1-16 w: wwwwwwwwwwwwwwwwwww\n',
#  '2-4 f: ffcf\n',
#  '13-14 h: sbchhxhhxrxdlb\n',
#  '8-10 s: sssxgcshsjs\n',
#  '18-19 t: tttttttpttttrtttttp\n',
#  '5-13 b: bdmpbkbjdhbbbqkb\n',
#  '3-5 z: wrskzzzq\n',
#  '7-10 f: fgfffffffffff\n',
#  '2-5 b: qrbmskdkbs\n',
#  '3-7 x: xnctxxkqxvz\n',
#  '14-15 d: dddddddddddvdtd\n',
#  '10-13 d: dddsrddzcldnbndntx\n',
#  '10-14 w: wwwwwwwwwwwwlwww\n',
#  '9-10 v: svvgsvvwvvvvvn\n',
#  '4-10 g: gggggggggggg\n',
#  '2-8 x: xgxxxxxr\n',
#  '3-11 b: fbrwbzfbbkbs\n',
#  '8-9 f: qvdxcfqffxdlhlndqj\n',
#  '8-13 k: rkxdkfkbxbskkkgvkk\n',
#  '5-9 t: xtttmtpsptztts\n',
#  '1-4 v: vvvkvvvvvvvvv\n',
#  '11-12 n: nnnnnnnnnnpn\n',
#  '1-2 f: htkv\n',
#  '3-7 s: qfszssf\n',
#  '4-5 j: njjjjjjj\n',
#  '7-8 f: fdffffbjfk\n',
#  '3-5 v: qcncphtnjnqvr\n',
#  '6-11 l: lmwlptlllllll\n',
#  '5-7 q: zvqlwqqcqqdqbm\n',
#  '2-6 h: hhhhhhh\n',
#  '5-9 v: nvslbccbvpqfgt\n',
#  '9-17 k: mzvbktkkkckktkkdkkk\n',
#  '5-6 f: fffflf\n',
#  '12-14 t: ttttttlttntptmth\n',
#  '17-18 k: flnshklxckpjkkzkkk\n',
#  '6-11 w: wwwwwwwwwwwwwwwf\n',
#  '9-13 j: jrpjjjwvjjjjjtzj\n',
#  '6-8 b: bbqbbfbzbb\n',
#  '10-13 q: qqqqqqqqqqqqq\n',
#  '12-15 t: blftxfwtsldttstztnt\n',
#  '4-5 g: mggqg\n',
#  '10-19 z: fzcvzpkznjrzgsfwzrv\n',
#  '5-9 t: txcgtnvnt\n',
#  '6-7 w: wwwwwdm\n',
#  '10-14 g: bgggglgtggggxkxggggg\n',
#  '6-8 f: srjfqgrr\n',
#  '2-4 w: wrbbwk\n',
#  '8-9 s: sdjcssswxn\n',
#  '7-8 w: zwwwwwwwwwv\n',
#  '1-5 l: llvlxll\n',
#  '1-18 h: hqbhdchhhhgqfhwhjh\n',
#  '8-12 t: dqttttthtttlttxnt\n',
#  '5-8 s: gssbtqsszscxsxt\n',
#  '8-9 r: rrdvrrlrxrrrf\n',
#  '7-14 s: xssrszdrqspbjk\n',
#  '2-5 l: lwllv\n',
#  '1-4 q: qdxkkdtqccdfpjlcjpsn\n',
#  '12-13 z: zzzzzzzzzzzjpz\n',
#  '1-8 r: gsrcbxpp\n',
#  '2-4 w: jwwwnd\n',
#  '2-4 w: mwmwsnmdrrmzstcqnfx\n',
#  '16-17 j: jjjjjjjjjjjjjjjzjj\n',
#  '10-11 w: vwsvvfwnfdzwwn\n',
#  '8-13 r: rrzrrrrrhrrrrrvrr\n',
#  '12-13 v: vvpvvvvvvvvcp\n',
#  '5-16 t: tptwxtzstbtstvlwt\n',
#  '3-4 x: nxxxx\n',
#  '3-4 w: hwpm\n',
#  '1-4 w: xkpw\n',
#  '2-7 t: tcnmnstc\n',
#  '10-14 v: bjvfmvwmlfmzvntvv\n',
#  '1-8 n: zdnmntxjznx\n',
#  '4-9 n: nnnnnnnnnfnnn\n',
#  '3-5 v: vvvvvkvvvvv\n',
#  '9-11 p: dbvrspsqpswqbs\n',
#  '3-11 l: lllllllxllll\n',
#  '15-16 t: tttjttttttttttvkt\n',
#  '2-5 z: zzhzt\n',
#  '4-5 x: xxxxxnx\n',
#  '1-4 r: rrrr\n',
#  '1-3 t: fpgvpvft\n',
#  '16-17 g: ggggzggggggggggggggg\n',
#  '6-7 f: fffffzd\n',
#  '3-8 t: tttttttttt\n',
#  '5-6 k: dpxbkk\n',
#  '9-10 s: sssssssssx\n',
#  '6-7 d: xdddddd\n',
#  '7-13 d: psjkdzdwkpzhdv\n',
#  '2-7 l: llllllxllllllllll\n',
#  '4-6 h: jhjhnhhhhhhhhldhhhj\n',
#  '15-16 q: qqdqkqqqtqqqtxrqqlt\n',
#  '2-14 f: tbthxfczjjkffffh\n',
#  '11-12 m: mlmnqvmhmpzz\n',
#  '13-15 l: llllllllclllzlpg\n',
#  '5-8 j: jjjjjjjj\n',
#  '2-3 g: gbmtnjgq\n',
#  '3-4 g: rgqfggl\n',
#  '10-15 w: wwxwwkwcwgwwbwx\n',
#  '4-5 w: wwwnd\n',
#  '3-6 h: vcpsbhhgkhrnjcpnhtv\n',
#  '2-6 q: qqqqqtxqq\n',
#  '8-10 l: lllllllnlm\n',
#  '3-4 c: ccgsg\n',
#  '2-12 p: fpfnfwvzrrwppgj\n',
#  '4-11 p: hxsjlvtxnpndg\n',
#  '1-2 h: tchph\n',
#  '3-5 w: tkhjdw\n',
#  '2-3 b: brkzbtl\n',
#  '13-14 d: dddbddwdvxjdcz\n',
#  '2-3 m: mmmf\n',
#  '7-8 r: rrrrdrrrr\n',
#  '6-8 w: hwwwwwwwqsq\n',
#  '6-7 x: sxkxbxxxtxxx\n',
#  '5-10 f: pqpffjxfzf\n',
#  '2-4 k: bknl\n',
#  '2-9 x: xxqxsxxtp\n',
#  '1-10 v: vzwhxdmfzkcvfjkltl\n',
#  '6-7 d: zdrfljdwr\n',
#  '10-11 h: bcngmvshhhh\n',
#  '11-12 t: ttttttttttft\n',
#  '7-8 b: rjbbbqbb\n',
#  '9-10 c: ccccccccdwc\n',
#  '14-15 h: hhthhhhhhhhhhhhhwhv\n',
#  '1-3 d: dsddfgb\n',
#  '14-15 v: vvvhvvvvvvvvvvvxv\n',
#  '5-8 w: wbswsttmqwzpdwwwts\n',
#  '5-7 w: vwdwtwmrljq\n',
#  '3-4 b: mzbbqsdhrtbdlf\n',
#  '2-5 n: prxnnn\n',
#  '6-11 g: fgggggggggkggb\n',
#  '5-10 q: kqpwlthzbvjwztmdttl\n',
#  '2-9 v: wkglnxwscznvqwjzg\n',
#  '1-13 x: xxxxxxxxxxxxfx\n',
#  '4-6 s: ssshsq\n',
#  '13-14 l: lljllmllglllllnlll\n',
#  '2-10 b: mbvlbjmhrj\n',
#  '4-14 j: pjpjkncfzchgzgpvcxsj\n',
#  '4-5 k: kkpnpkkr\n',
#  '5-8 x: xdtxdxxxxmffxxf\n',
#  '1-6 n: nnnnnn\n',
#  '3-4 r: btmrrdr\n',
#  '1-5 c: ccccfccccccccc\n',
#  '5-6 q: qwpqqq\n',
#  '2-8 h: gxhhppdf\n',
#  '7-9 l: llhllhlll\n',
#  '13-17 f: fffffffffffffffff\n',
#  '1-14 w: wtvkwddfbpklwwtqf\n',
#  '1-4 j: pjjj\n',
#  '4-6 t: tltcszzt\n',
#  '2-11 k: skjzfjrfktsbvkk\n',
#  '3-5 f: cfmfbgfs\n',
#  '7-10 h: hhchhhrrhfhhzrh\n',
#  '2-3 n: nnrkn\n',
#  '3-5 s: lsvcwg\n',
#  '19-20 r: rrrrrrrrrrrrrrcrrrrt\n',
#  '5-11 h: hkhbhghxhhh\n',
#  '7-9 m: bhrmwpfmv\n',
#  '3-4 n: nnzzs\n',
#  '5-10 n: nnnnnndnncvnnj\n',
#  '1-2 n: nfnd\n',
#  '4-6 l: klwldlvllnt\n',
#  '1-9 k: kkkkkkkkkk\n',
#  '2-3 m: cjhq\n',
#  '7-10 l: lllllllllll\n',
#  '15-16 j: jlwvstmfjjjjrgcr\n',
#  '5-7 d: vfdrddjwdp\n',
#  '4-6 t: tttrtl\n',
#  '3-10 g: dxjmwdhqgslgkvz\n',
#  '12-15 d: dddldddddtdmldw\n',
#  '2-3 v: dvvtbht\n',
#  '7-9 n: nlnnnmvnnnnnkn\n',
#  '4-8 v: kvvtvlvs\n',
#  '2-9 f: ffffgvxsfpxfxzr\n',
#  '4-5 z: czzbwwzzzw\n',
#  '5-6 x: hjxxldx\n',
#  '5-7 b: bwbxmbshlvp\n',
#  '3-4 f: pzffwr\n',
#  '5-6 r: frlgnhmrf\n',
#  '2-3 w: kwwd\n',
#  '4-5 s: szsrs\n',
#  '11-12 j: jjjjjjjjjjhc\n',
#  '3-4 v: vvvv\n',
#  '4-5 b: pbggdlhbbdfdj\n',
#  '3-12 j: njrbhvwxmmwfrfmmbw\n',
#  '15-16 m: qqvbjcmrmhmlljnj\n',
#  '1-9 h: hhhhhhhhmchhhhhhhh\n',
#  '6-11 p: ppppppppppgpp\n',
#  '14-15 p: gppgpbprpppzppppvp\n',
#  '3-15 z: zzgmzzzxzzxzzzqz\n',
#  '7-9 x: rxxxxxxxrvwxxx\n',
#  '4-5 x: jxxsxxxq\n',
#  '5-7 t: xtggtktxt\n',
#  '19-20 m: mmvvmmmmlmzmmmmqmmmt\n',
#  '1-3 z: zzzzzcznzzzz\n',
#  '1-5 t: zqthftmx\n',
#  '3-9 x: rwxxmxnxxx\n',
#  '11-12 x: xxxxxxxxxxwh\n',
#  '11-15 v: vvvvvvtvvvvvpvcv\n',
#  '14-17 d: dddddddddddddddddd\n',
#  '13-17 l: llllllllllllllllhlll\n',
#  '3-8 m: mtrnwmdmmq\n',
#  '15-16 n: nnnnnnnnnnnnnnrcnnn\n',
#  '9-11 w: wfwwwwctwwq\n',
#  '7-10 b: bbbsbbbbbbkbbbb\n',
#  '12-18 k: thxrfrwhzxhfpnjqkk\n',
#  '3-4 f: wffs\n',
#  '1-4 t: tmvktrpdt\n',
#  '5-8 k: kkkkskkw\n',
#  '9-12 w: wgwwwwwwwwwww\n',
#  '6-7 r: rrrprfc\n',
#  '2-4 g: gxgk\n',
#  '9-12 p: hjpppppppphb\n',
#  '7-11 f: fffffffvfffff\n',
#  '1-4 r: bclrhrqlpjmrv\n',
#  '7-15 s: lgrsrpskbgsmqgw\n',
#  '8-14 j: jhqfjjjjjjjjjjj\n',
#  '10-11 d: dddddgfdddddd\n',
#  '3-4 j: gjrm\n',
#  '1-5 x: xgvwrx\n',
#  '2-11 r: lrxrzvplwxq\n',
#  '5-10 f: xffffffffff\n',
#  '3-4 g: ssgrflgvgg\n',
#  '9-18 d: dlrqctvdrdcddrxjbd\n',
#  '2-5 p: pppppp\n',
#  '2-4 l: fscks\n',
#  '2-18 v: pgvgxwwljphbkfwlhv\n',
#  '1-3 h: xdmnfptbgghqbzvrd\n',
#  '13-16 q: sqqqqqqqqqqqqqjq\n',
#  '4-6 v: vvvvtv\n',
#  '11-16 b: bbbbbvbbbbblpbmbb\n',
#  '9-15 l: vcqwdtfblfwxpqv\n',
#  '2-5 c: cfccm\n',
#  '4-5 g: ggglvzgpg\n',
#  '6-7 w: wwwdwgwfkwnkw\n',
#  '3-4 d: dsbd\n',
#  '7-8 g: ggfggghg\n',
#  '2-10 x: xxxxxnxkxflmxxjxxx\n',
#  '5-7 h: pthdhsz\n',
#  '3-7 p: xcndbvbbh\n',
#  '9-11 n: nhnnnqnnlcwnn\n',
#  '3-4 p: pbpp\n',
#  '2-5 h: hshhz\n',
#  '9-13 g: grkngqlwbkrjn\n',
#  '14-19 r: rrrrrrrrrrrrrrgrrrrr\n',
#  '2-3 r: krtcfphwm\n',
#  '9-10 v: vwvvvvvwsvvqvv\n',
#  '2-5 b: kbmgpbrn\n',
#  '4-7 l: lzlmlltll\n',
#  '13-17 w: wwwwwwwwwwwwcwwwpw\n',
#  '1-3 q: qtqh\n',
#  '1-3 v: fxbcv\n',
#  '6-11 v: vvvxvvvmbvpvh\n',
#  '5-18 s: ssxpkssmgnssssldsvss\n',
#  '11-13 q: qqqqqqsqfqqqq\n',
#  '1-7 r: wrprrjvrrrrwrrrr\n',
#  '13-17 q: qqqqqqtqqqqqmqqqq\n',
#  '12-13 f: ftwffffftfxffqtbxfff\n',
#  '12-16 r: tzqrqrwlnrrhkpgn\n',
#  '5-6 p: pppbgpp\n',
#  '9-10 r: rgrrxnrrrr\n',
#  '16-17 d: dxkfdrdtmdlchlddd\n',
#  '7-9 k: kkkktkkkkk\n',
#  '6-8 p: pppppppc\n',
#  '11-17 j: jjjjjjjjjjjjjjjjjjjj\n',
#  '8-9 q: qqqqkccwmqjqqq\n',
#  '7-10 c: cccflcccccjsh\n',
#  '3-18 k: dbzgrzqppcvkkjmskpr\n',
#  '2-9 v: rvwbhvhpwjmf\n',
#  '6-10 s: swhsspsshc\n',
#  '1-3 n: nnnt\n',
#  '13-14 s: dzqvjztkgsnbsbs\n',
#  '1-5 n: nnsnnnn\n',
#  '9-17 v: vvvzvvvvqvvxvvzvpv\n',
#  '7-10 m: gdqmmhmxmt\n',
#  '6-12 d: dfdkrvjdwbgg\n',
#  '1-8 q: qqfqtqtq\n',
#  '8-9 n: nnnnsnnhmn\n',
#  '2-4 p: pwpz\n',
#  '2-5 r: wlzzk\n',
#  '4-6 z: zplxzzz\n',
#  '6-11 s: sssssrssssx\n',
#  '16-18 t: ttvttttwtttttttvtlbt\n',
#  '1-12 r: rgsrkfgmrbbbhcrtr\n',
#  '11-15 n: pgqnnnnnnsnfwnw\n',
#  '2-4 b: dthd\n',
#  '5-10 r: xkllrwxbvrrbtlk\n',
#  '17-19 w: wwwwwwwwwwwwwwwwwwv\n',
#  '5-7 t: ztcsdtqts\n',
#  '1-5 b: vbfbd\n',
#  '6-12 g: kzggwgcgggthglgmg\n',
#  '14-15 l: xlhlglllllsllmvdllll\n',
#  '1-6 l: lglldglpqlxr\n',
#  '9-10 p: wpppqpptppppnp\n',
#  '2-20 s: ghrpccsrgqzgrcbqhjjb\n',
#  '2-15 f: fnfflfmgfbwhfwffdtd\n',
#  '1-2 v: vbpcktv\n',
#  '15-16 r: rrrrjvsqjrvrjntdrd\n',
#  '14-18 z: zzzzzzzzzzzzzqzzzk\n',
#  '12-16 h: hhhhhhhhhhhhhhhhhl\n',
#  '17-18 b: hbbfjdblmbnbgsbcdwg\n',
#  '3-5 b: xnbbbtb\n',
#  '3-10 x: xqxmxrvsxxwxth\n',
#  '4-6 q: qqqqqqq\n',
#  '8-9 r: rrrrrrrrr\n',
#  '12-16 q: qrqqqzgxcqqrqqxv\n',
#  '10-11 p: rppppppphtndp\n',
#  '2-7 h: zhhpjkhvplbr\n',
#  '13-15 l: llllllllllllllp\n',
#  '15-18 k: kkkkkkkkkkkkkkkkkk\n',
#  '2-4 g: ggjgl\n',
#  '3-7 g: xpnjmsgtgqmxn\n',
#  '1-2 k: kcgktft\n',
#  '9-10 j: jjjjjjjqjjj\n',
#  '2-7 b: fbbbbbbbbthbwc\n',
#  '3-7 j: phpptgrjppxw\n',
#  '8-9 m: qrgmtmbqhrx\n',
#  '8-10 l: hldllllzblllllvd\n',
#  '11-18 b: bmbbbtnwtbpbhdfwzz\n',
#  '1-5 h: hthbhsplh\n',
#  '2-6 g: wxgtvtcznqf\n',
#  '4-5 s: sssss\n',
#  '2-3 f: ffffff\n',
#  '3-4 k: krtm\n',
#  '2-7 q: qqlbcqqq\n',
#  '4-5 f: fffffwnh\n',
#  '6-8 k: lkwkkpkk\n',
#  '11-12 t: kchhtptngttttgtl\n',
#  '18-19 m: mmmmmmzmmmfmmmmmmscm\n',
#  '8-10 n: znsnmrnrnnmf\n',
#  '1-12 v: vdjkjhvwbbbrnz\n',
#  '1-2 k: rkjsrzkckvkbzzd\n',
#  '5-6 d: dwdddzd\n',
#  '7-8 d: ddddwddddj\n',
#  '8-9 w: wwwwwwwxww\n']

# %%
split = lines[0].strip().split(" ")
numRange = split[0].split("-")
letter = split[1][0]
txt = split[2]
print(f"{numRange},{letter},{txt}")
# Out:
# ['15', '16'],p,ppppppppppplppppp

# %%
cr = 0
for line in lines:
    split = line.strip().split(" ")
    minN = int(split[0].split("-")[0])
    maxN = int(split[0].split("-")[1])
    letter = split[1][0]
    txt = split[2]

    c = 0
    for l in txt:
        if l ==  letter:
            c += 1
    if int(c) >= minN and int(c) <= maxN:
        cr += 1
print(cr)
# Out:
# 572

# %%
cr = 0
for line in lines:
    split = line.strip().split(" ")
    minN = int(split[0].split("-")[0]) - 1
    maxN = int(split[0].split("-")[1]) - 1
    letter = split[1][0]
    txt = split[2]

    c = 0
    if len(txt) > minN and txt[minN] == letter:
        c += 1
    if len(txt) > maxN and txt[maxN] == letter:
        c += 1
    if (c == 1):
        cr += 1
        #print(f"text: '{txt}', min: '{minN}', max: '{maxN}', letter: '{letter}'")
    
print(cr)
# Out:
# text: 'xvrwfmkmmmc', min: '3', max: '8', letter: 'm'
# text: 'wwwwdwwwwwwwwnwww', min: '13', max: '14', letter: 'w'
# text: 'qhqdljqtdqqdqqjjcqq', min: '6', max: '15', letter: 'q'
# text: 'hdpzqqzpngbsmncssscl', min: '17', max: '19', letter: 's'
# text: 'xxfxxxxxxbkxjzxxxxxq', min: '2', max: '7', letter: 'x'
# text: 'gqqjqqq', min: '3', max: '4', letter: 'q'
# text: 'cckkkkdxkhhkkwkzkl', min: '7', max: '14', letter: 'k'
# text: 'skppkkhjsskkkwzml', min: '2', max: '10', letter: 'k'
# text: 'tbchbbbfjbbldgkbb', min: '6', max: '7', letter: 'b'
# text: 'vvvvvvvvvvvxvvvvv', min: '11', max: '15', letter: 'v'
# text: 'mzdfpmn', min: '4', max: '5', letter: 'm'
# text: 'sssssssssssssmsss', min: '3', max: '13', letter: 's'
# text: 'ttktgjstttrtt', min: '0', max: '4', letter: 't'
# text: 'zzqj', min: '0', max: '2', letter: 'z'
# text: 'ttgtttkttttdgqg', min: '6', max: '9', letter: 't'
# text: 'mtmmmm', min: '1', max: '3', letter: 'm'
# text: 'hnjhjkmkvhhhgdrvnz', min: '0', max: '7', letter: 'h'
# text: 'mmmmzmmx', min: '5', max: '7', letter: 'm'
# text: 'kkkmkkjj', min: '5', max: '6', letter: 'k'
# text: 'vvhtvsmnvwwhv', min: '4', max: '7', letter: 'v'
# text: 'xnnnnnnksnn', min: '6', max: '8', letter: 'n'
# text: 'mjmmvqmmdf', min: '5', max: '6', letter: 'm'
# text: 'shmvnmsmmsssgsg', min: '1', max: '13', letter: 's'
# text: 'xqqqqqgq', min: '5', max: '6', letter: 'q'
# text: 'rpppqhnfjpppbdlpfvwl', min: '0', max: '11', letter: 'p'
# text: 'tmmrmmxtmmmmhmsmmmlm', min: '5', max: '18', letter: 'm'
# text: 'mmlmmmmmbm', min: '4', max: '8', letter: 'm'
# text: 'tttttjtmtttttttbtkpt', min: '10', max: '17', letter: 't'
# text: 'ssshsg', min: '3', max: '4', letter: 's'
# text: 'rrrrvhrrrrrrrrrrhjrr', min: '13', max: '16', letter: 'r'
# text: 'ggggdp', min: '3', max: '5', letter: 'g'
# text: 'cccpcccmcccwjcvgcc', min: '4', max: '11', letter: 'c'
# text: 'gxggcgggfgglgg', min: '10', max: '11', letter: 'g'
# text: 'ddddddddddddddddddwd', min: '2', max: '18', letter: 'd'
# text: 'xlcx', min: '0', max: '2', letter: 'x'
# text: 'bbbqbbqb', min: '3', max: '4', letter: 'b'
# text: 'lldllvlllt', min: '5', max: '6', letter: 'l'
# text: 'kfdsffbrpczwfk', min: '3', max: '4', letter: 'f'
# text: 'rbbbb', min: '0', max: '4', letter: 'b'
# text: 'rrrrrrrrrmwr', min: '10', max: '11', letter: 'r'
# text: 'sssc', min: '2', max: '3', letter: 's'
# text: 'jwhbwzftrjrdzbjkb', min: '15', max: '16', letter: 'b'
# text: 'xxpxx', min: '2', max: '3', letter: 'x'
# text: 'ppwqppbpslpppfphzmz', min: '7', max: '18', letter: 'p'
# text: 'bbbbbbbbzb', min: '2', max: '8', letter: 'b'
# text: 'rrbfkb', min: '1', max: '2', letter: 'b'
# text: 'pppppzjfp', min: '4', max: '6', letter: 'p'
# text: 'fgwgpggpg', min: '2', max: '6', letter: 'g'
# text: 'wwwwpmdnxwlm', min: '1', max: '4', letter: 'w'
# text: 'mtjcmmm', min: '0', max: '1', letter: 'm'
# text: 'fjkf', min: '2', max: '3', letter: 'f'
# text: 'vvvvvrvvjnv', min: '2', max: '8', letter: 'v'
# text: 'xjvhxxkxxx', min: '2', max: '5', letter: 'x'
# text: 'pcppq', min: '2', max: '4', letter: 'p'
# text: 'kkqkk', min: '2', max: '4', letter: 'k'
# text: 'lhnnnbcctjvfflcpl', min: '5', max: '16', letter: 'b'
# text: 'mmmmmvmmmpmmm', min: '9', max: '10', letter: 'm'
# text: 'nnnnnnnnnnxnnnbnnfn', min: '15', max: '17', letter: 'n'
# text: 'vvvvvvvvvvpv', min: '2', max: '10', letter: 'v'
# text: 'cddncjdmvfdr', min: '4', max: '10', letter: 'd'
# text: 'cjpj', min: '2', max: '3', letter: 'j'
# text: 'bjnqkjzhsxgmznrj', min: '2', max: '6', letter: 'n'
# text: 'bbbbrbb', min: '2', max: '4', letter: 'b'
# text: 'ddjdfddzdd', min: '6', max: '7', letter: 'd'
# text: 'xfczlllvlvlllnllxw', min: '4', max: '9', letter: 'l'
# text: 'tttktksttdtttt', min: '9', max: '10', letter: 't'
# text: 'vlcl', min: '0', max: '3', letter: 'l'
# text: 'bbtbx', min: '3', max: '4', letter: 'b'
# text: 'kxdxwxbxxxxjkxxxdjzc', min: '13', max: '19', letter: 'x'
# text: 'swsssssssslssl', min: '12', max: '13', letter: 's'
# text: 'xgmc', min: '2', max: '3', letter: 'c'
# text: 'rqpprwwktjpmnjqpx', min: '2', max: '6', letter: 'p'
# text: 'sphwrndcqtlzcbrsppr', min: '0', max: '13', letter: 's'
# text: 'hcccncncczccc', min: '2', max: '4', letter: 'c'
# text: 'dvddddd', min: '1', max: '6', letter: 'd'
# text: 'vvvvvvvvvkcvvvvvmbv', min: '14', max: '17', letter: 'v'
# text: 'dddddddddhdddddd', min: '9', max: '15', letter: 'd'
# text: 'wghgnmg', min: '0', max: '3', letter: 'g'
# text: 'xfznfnncfnnnnmnqnn', min: '5', max: '13', letter: 'n'
# text: 'dcxdzfjdqjhlprmlgr', min: '0', max: '8', letter: 'd'
# text: 'sgghtdkbllvjddhdddrd', min: '4', max: '5', letter: 'd'
# text: 'ftwmgvxwcnbnhnxlvdfl', min: '7', max: '15', letter: 'w'
# text: 'jldsrczptcggwvd', min: '3', max: '14', letter: 'd'
# text: 'qqqqqqqqqqqqqnqqqqq', min: '13', max: '17', letter: 'q'
# text: 'qqtqqdqqqqqqvxqq', min: '7', max: '13', letter: 'q'
# text: 'lnfhdndhtnlnpnnf', min: '5', max: '6', letter: 'n'
# text: 'rbcrqqcbmcddnpwc', min: '14', max: '15', letter: 'c'
# text: 'jjjjzmkjljzwmjjqbjq', min: '7', max: '10', letter: 'j'
# text: 'vfjhvjqcjnzpl', min: '2', max: '3', letter: 'j'
# text: 'cvcc', min: '1', max: '3', letter: 'c'
# text: 'jhqdjfnfft', min: '3', max: '7', letter: 'f'
# text: 'lprvzvvvvvvvhvvmvvv', min: '15', max: '16', letter: 'v'
# text: 'lllzllldplhdllll', min: '10', max: '13', letter: 'l'
# text: 'cjcccfccscwcclcccb', min: '10', max: '12', letter: 'c'
# text: 'mllljlllllllllllllt', min: '11', max: '18', letter: 'l'
# text: 'rrrrrrrrrbr', min: '6', max: '9', letter: 'r'
# text: 'rgrrsrrrwrrr', min: '6', max: '8', letter: 'r'
# text: 'mppxpp', min: '0', max: '5', letter: 'p'
# text: 'nckkmkzkxg', min: '3', max: '4', letter: 'k'
# text: 'rrmrcgrrrlrq', min: '1', max: '4', letter: 'r'
# text: 'ppppfp', min: '4', max: '5', letter: 'p'
# text: 'mmmmmmmml', min: '7', max: '8', letter: 'm'
# text: 'sssssssssssssb', min: '12', max: '13', letter: 's'
# text: 'mdddcdsddddrdd', min: '1', max: '11', letter: 'd'
# text: 'zzzzzzzzzzzzrzz', min: '5', max: '12', letter: 'z'
# text: 'rwrrtrsrrpr', min: '3', max: '6', letter: 'r'
# text: 'lgpkjldqwvhntvwgb', min: '1', max: '8', letter: 'g'
# text: 'xdttntttvtzttzjf', min: '6', max: '10', letter: 't'
# text: 'cnvvjrzvvvvvprfrv', min: '7', max: '14', letter: 'v'
# text: 'vggmh', min: '0', max: '1', letter: 'g'
# text: 'ssssssvsssssssssp', min: '15', max: '16', letter: 's'
# text: 'jhhhhhwmh', min: '5', max: '7', letter: 'h'
# text: 'rmnclfgn', min: '6', max: '7', letter: 'n'
# text: 'bmgtgwjnrdq', min: '2', max: '5', letter: 'g'
# text: 'gvvczkkmtsgtpsgbg', min: '10', max: '11', letter: 'g'
# text: 'slvljjkbtjdqvq', min: '2', max: '5', letter: 'j'
# text: 'xcdwvgrrrprzflmrcv', min: '4', max: '6', letter: 'r'
# text: 'bdbdvlllltlv', min: '3', max: '5', letter: 'l'
# text: 'sxsssqsqsssvsssssss', min: '5', max: '13', letter: 's'
# text: 'mjxxk', min: '2', max: '4', letter: 'x'
# text: 'qcgpvw', min: '4', max: '5', letter: 'v'
# text: 'ljjllpklctzlv', min: '4', max: '6', letter: 'l'
# text: 'jmjgwjjjjjtfj', min: '1', max: '9', letter: 'j'
# text: 'jjkmjmjbjj', min: '4', max: '5', letter: 'j'
# text: 'rrrfrrzrrg', min: '5', max: '6', letter: 'r'
# text: 'nnnnnknnnnnnjnnnnn', min: '3', max: '5', letter: 'n'
# text: 'nnnnnnnnw', min: '6', max: '8', letter: 'n'
# text: 'qqqqqvqqq', min: '2', max: '5', letter: 'q'
# text: 'llxdwx', min: '4', max: '5', letter: 'x'
# text: 'ksghkhvzkxjgxks', min: '0', max: '9', letter: 'k'
# text: 'vvmmbmmvkmmmm', min: '7', max: '11', letter: 'm'
# text: 'xtlntfwttnp', min: '7', max: '10', letter: 't'
# text: 'dmqpdshshh', min: '4', max: '8', letter: 'h'
# text: 'kswkfhkzkkr', min: '5', max: '8', letter: 'k'
# text: 'mxmdmqmxhsdrms', min: '2', max: '7', letter: 'm'
# text: 'pbbbbbbbbbbbkbbbbbpb', min: '16', max: '18', letter: 'b'
# text: 'snlcnszdc', min: '1', max: '6', letter: 'n'
# text: 'qmmz', min: '0', max: '2', letter: 'm'
# text: 'lllllllrlllll', min: '0', max: '7', letter: 'l'
# text: 'vvvvzsvx', min: '2', max: '7', letter: 'v'
# text: 'sqtqlqqvqqqqqfqdw', min: '14', max: '15', letter: 'q'
# text: 'lcdd', min: '1', max: '2', letter: 'd'
# text: 'jjdt', min: '0', max: '3', letter: 'j'
# text: 'bnfmvmmmmsmmmm', min: '8', max: '9', letter: 'm'
# text: 'gzcvchdwdbq', min: '0', max: '2', letter: 'c'
# text: 'xrvvvwn', min: '1', max: '2', letter: 'v'
# text: 'bhgrzzjzgzmzzzzz', min: '6', max: '13', letter: 'z'
# text: 'ppnptchxppvw', min: '0', max: '2', letter: 'p'
# text: 'xzmkxrvxqxvt', min: '3', max: '7', letter: 'x'
# text: 'wwwmw', min: '3', max: '4', letter: 'w'
# text: 'rlhprqxswxckpxh', min: '1', max: '6', letter: 'x'
# text: 'nhltlhq', min: '4', max: '6', letter: 'l'
# text: 'tnttwrhttt', min: '4', max: '8', letter: 't'
# text: 'fnwszlmqhlzdzhmkmt', min: '2', max: '17', letter: 't'
# text: 'bbmbbbzzbbbnbbx', min: '2', max: '3', letter: 'b'
# text: 'qqqqqqqqqfqqqfq', min: '13', max: '14', letter: 'q'
# text: 'plnxmrxxxrkv', min: '3', max: '4', letter: 'x'
# text: 'vvxvvwv', min: '0', max: '5', letter: 'v'
# text: 'zbwrgrk', min: '0', max: '4', letter: 'g'
# text: 'xqvp', min: '1', max: '3', letter: 'p'
# text: 'lqlm', min: '0', max: '3', letter: 'l'
# text: 'jjhjjjpj', min: '6', max: '7', letter: 'j'
# text: 'zzzzzzzqzzzpz', min: '11', max: '12', letter: 'z'
# text: 'qptzdzpsppppn', min: '4', max: '11', letter: 'p'
# text: 'kkkkkkkkkkkkkgkkkkk', min: '13', max: '18', letter: 'k'
# text: 'vvpdvfvvvvvttpcv', min: '7', max: '11', letter: 'v'
# text: 'sddxfd', min: '2', max: '3', letter: 'd'
# text: 'kkkkkkkklkk', min: '6', max: '8', letter: 'k'
# text: 'bhcmm', min: '0', max: '4', letter: 'm'
# text: 'sspsssttslsssslwss', min: '7', max: '13', letter: 's'
# text: 'qkjk', min: '2', max: '3', letter: 'k'
# text: 'wwwwqww', min: '3', max: '4', letter: 'w'
# text: 'qkktgxrsfxgknrj', min: '8', max: '13', letter: 'r'
# text: 'qqqqqsvqqqqwqqqq', min: '11', max: '15', letter: 'q'
# text: 'mdwd', min: '0', max: '2', letter: 'w'
# text: 'jjjjjjjbj', min: '7', max: '8', letter: 'j'
# text: 'mkkklkkkkvkkmpknvkk', min: '8', max: '16', letter: 'k'
# text: 'htgghp', min: '3', max: '4', letter: 'g'
# text: 'ccczcggccxccclcccgc', min: '17', max: '18', letter: 'c'
# text: 'pfnp', min: '1', max: '3', letter: 'p'
# text: 'jjljjjjjvjjjjjjjjtj', min: '8', max: '15', letter: 'j'
# text: 'dkqrqp', min: '4', max: '5', letter: 'q'
# text: 'hhfwhhd', min: '2', max: '5', letter: 'h'
# text: 'mfqcdghqmxqzcljczqt', min: '3', max: '7', letter: 'q'
# text: 'nktl', min: '0', max: '2', letter: 't'
# text: 'wwwwwwwwwwpwwww', min: '10', max: '13', letter: 'w'
# text: 'llqglv', min: '1', max: '2', letter: 'l'
# text: 'rxjx', min: '2', max: '3', letter: 'x'
# text: 'wpwwwwwqgwwwwhsw', min: '6', max: '13', letter: 'w'
# text: 'bxzwjqdwpwlwjn', min: '0', max: '3', letter: 'w'
# text: 'zmjrzzzzzszzzslzzmzz', min: '9', max: '16', letter: 'z'
# text: 'wlwwwwwwpwj', min: '4', max: '10', letter: 'w'
# text: 'ssssssssqs', min: '8', max: '9', letter: 's'
# text: 'cbdhd', min: '1', max: '2', letter: 'd'
# text: 'jjjjxjjjjjjqjjjjjj', min: '4', max: '15', letter: 'j'
# text: 'qqpqmqqzqbqqkn', min: '7', max: '11', letter: 'q'
# text: 'qqqqwqqqqqfqqq', min: '4', max: '12', letter: 'q'
# text: 'kzwvwzqrmvn', min: '1', max: '8', letter: 'm'
# text: 'fscccgc', min: '2', max: '5', letter: 'c'
# text: 'vfctz', min: '3', max: '4', letter: 't'
# text: 'rrlr', min: '2', max: '3', letter: 'r'
# text: 'tttttttpttttrtttttp', min: '17', max: '18', letter: 't'
# text: 'wrskzzzq', min: '2', max: '4', letter: 'z'
# text: 'dddddddddddvdtd', min: '13', max: '14', letter: 'd'
# text: 'fbrwbzfbbkbs', min: '2', max: '10', letter: 'b'
# text: 'rkxdkfkbxbskkkgvkk', min: '7', max: '12', letter: 'k'
# text: 'vvvkvvvvvvvvv', min: '0', max: '3', letter: 'v'
# text: 'nnnnnnnnnnpn', min: '10', max: '11', letter: 'n'
# text: 'qfszssf', min: '2', max: '6', letter: 's'
# text: 'lmwlptlllllll', min: '5', max: '10', letter: 'l'
# text: 'zvqlwqqcqqdqbm', min: '4', max: '6', letter: 'q'
# text: 'nvslbccbvpqfgt', min: '4', max: '8', letter: 'v'
# text: 'fffflf', min: '4', max: '5', letter: 'f'
# text: 'mggqg', min: '3', max: '4', letter: 'g'
# text: 'bgggglgtggggxkxggggg', min: '9', max: '13', letter: 'g'
# text: 'llvlxll', min: '0', max: '4', letter: 'l'
# text: 'gssbtqsszscxsxt', min: '4', max: '7', letter: 's'
# text: 'rrdvrrlrxrrrf', min: '7', max: '8', letter: 'r'
# text: 'qdxkkdtqccdfpjlcjpsn', min: '0', max: '3', letter: 'q'
# text: 'jjjjjjjjjjjjjjjzjj', min: '15', max: '16', letter: 'j'
# text: 'xkpw', min: '0', max: '3', letter: 'w'
# text: 'tcnmnstc', min: '1', max: '6', letter: 't'
# text: 'dbvrspsqpswqbs', min: '8', max: '10', letter: 'p'
# text: 'zzhzt', min: '1', max: '4', letter: 'z'
# text: 'sssssssssx', min: '8', max: '9', letter: 's'
# text: 'llllllxllllllllll', min: '1', max: '6', letter: 'l'
# text: 'qqdqkqqqtqqqtxrqqlt', min: '14', max: '15', letter: 'q'
# text: 'tbthxfczjjkffffh', min: '1', max: '13', letter: 'f'
# text: 'vcpsbhhgkhrnjcpnhtv', min: '2', max: '5', letter: 'h'
# text: 'qqqqqtxqq', min: '1', max: '5', letter: 'q'
# text: 'bknl', min: '1', max: '3', letter: 'k'
# text: 'xxqxsxxtp', min: '1', max: '8', letter: 'x'
# text: 'vzwhxdmfzkcvfjkltl', min: '0', max: '9', letter: 'v'
# text: 'zdrfljdwr', min: '5', max: '6', letter: 'd'
# text: 'ttttttttttft', min: '10', max: '11', letter: 't'
# text: 'prxnnn', min: '1', max: '4', letter: 'n'
# text: 'fgggggggggkggb', min: '5', max: '10', letter: 'g'
# text: 'xxxxxxxxxxxxfx', min: '0', max: '12', letter: 'x'
# text: 'mbvlbjmhrj', min: '1', max: '9', letter: 'b'
# text: 'pjpjkncfzchgzgpvcxsj', min: '3', max: '13', letter: 'j'
# text: 'xdtxdxxxxmffxxf', min: '4', max: '7', letter: 'x'
# text: 'btmrrdr', min: '2', max: '3', letter: 'r'
# text: 'ccccfccccccccc', min: '0', max: '4', letter: 'c'
# text: 'pjjj', min: '0', max: '3', letter: 'j'
# text: 'skjzfjrfktsbvkk', min: '1', max: '10', letter: 'k'
# text: 'nnrkn', min: '1', max: '2', letter: 'n'
# text: 'rrrrrrrrrrrrrrcrrrrt', min: '18', max: '19', letter: 'r'
# text: 'nnnnnndnncvnnj', min: '4', max: '9', letter: 'n'
# text: 'nfnd', min: '0', max: '1', letter: 'n'
# text: 'vfdrddjwdp', min: '4', max: '6', letter: 'd'
# text: 'nlnnnmvnnnnnkn', min: '6', max: '8', letter: 'n'
# text: 'szsrs', min: '3', max: '4', letter: 's'
# text: 'hhhhhhhhmchhhhhhhh', min: '0', max: '8', letter: 'h'
# text: 'ppppppppppgpp', min: '5', max: '10', letter: 'p'
# text: 'rxxxxxxxrvwxxx', min: '6', max: '8', letter: 'x'
# text: 'jxxsxxxq', min: '3', max: '4', letter: 'x'
# text: 'mmvvmmmmlmzmmmmqmmmt', min: '18', max: '19', letter: 'm'
# text: 'vvvvvvtvvvvvpvcv', min: '10', max: '14', letter: 'v'
# text: 'llllllllllllllllhlll', min: '12', max: '16', letter: 'l'
# text: 'mtrnwmdmmq', min: '2', max: '7', letter: 'm'
# text: 'wfwwwwctwwq', min: '8', max: '10', letter: 'w'
# text: 'thxrfrwhzxhfpnjqkk', min: '11', max: '17', letter: 'k'
# text: 'wffs', min: '2', max: '3', letter: 'f'
# text: 'tmvktrpdt', min: '0', max: '3', letter: 't'
# text: 'hjpppppppphb', min: '8', max: '11', letter: 'p'
# text: 'bclrhrqlpjmrv', min: '0', max: '3', letter: 'r'
# text: 'lgrsrpskbgsmqgw', min: '6', max: '14', letter: 's'
# text: 'xgvwrx', min: '0', max: '4', letter: 'x'
# text: 'lrxrzvplwxq', min: '1', max: '10', letter: 'r'
# text: 'ssgrflgvgg', min: '2', max: '3', letter: 'g'
# text: 'dlrqctvdrdcddrxjbd', min: '8', max: '17', letter: 'd'
# text: 'pgvgxwwljphbkfwlhv', min: '1', max: '17', letter: 'v'
# text: 'vcqwdtfblfwxpqv', min: '8', max: '14', letter: 'l'
# text: 'wwwdwgwfkwnkw', min: '5', max: '6', letter: 'w'
# text: 'dsbd', min: '2', max: '3', letter: 'd'
# text: 'ggfggghg', min: '6', max: '7', letter: 'g'
# text: 'xxxxxnxkxflmxxjxxx', min: '1', max: '9', letter: 'x'
# text: 'pthdhsz', min: '4', max: '6', letter: 'h'
# text: 'krtcfphwm', min: '1', max: '2', letter: 'r'
# text: 'vwvvvvvwsvvqvv', min: '8', max: '9', letter: 'v'
# text: 'kbmgpbrn', min: '1', max: '4', letter: 'b'
# text: 'vvvxvvvmbvpvh', min: '5', max: '10', letter: 'v'
# text: 'qqqqqqtqqqqqmqqqq', min: '12', max: '16', letter: 'q'
# text: 'pppbgpp', min: '4', max: '5', letter: 'p'
# text: 'pppppppc', min: '5', max: '7', letter: 'p'
# text: 'rvwbhvhpwjmf', min: '1', max: '8', letter: 'v'
# text: 'dzqvjztkgsnbsbs', min: '12', max: '13', letter: 's'
# text: 'gdqmmhmxmt', min: '6', max: '9', letter: 'm'
# text: 'zplxzzz', min: '3', max: '5', letter: 'z'
# text: 'rgsrkfgmrbbbhcrtr', min: '0', max: '11', letter: 'r'
# text: 'pgqnnnnnnsnfwnw', min: '10', max: '14', letter: 'n'
# text: 'wwwwwwwwwwwwwwwwwwv', min: '16', max: '18', letter: 'w'
# text: 'kzggwgcgggthglgmg', min: '5', max: '11', letter: 'g'
# text: 'lglldglpqlxr', min: '0', max: '5', letter: 'l'
# text: 'fnfflfmgfbwhfwffdtd', min: '1', max: '14', letter: 'f'
# text: 'vbpcktv', min: '0', max: '1', letter: 'v'
# text: 'llllllllllllllp', min: '12', max: '14', letter: 'l'
# text: 'xpnjmsgtgqmxn', min: '2', max: '6', letter: 'g'
# text: 'kcgktft', min: '0', max: '1', letter: 'k'
# text: 'hldllllzblllllvd', min: '7', max: '9', letter: 'l'
# text: 'lkwkkpkk', min: '5', max: '7', letter: 'k'
# text: 'znsnmrnrnnmf', min: '7', max: '9', letter: 'n'
# text: 'vdjkjhvwbbbrnz', min: '0', max: '11', letter: 'v'
# text: 'rkjsrzkckvkbzzd', min: '0', max: '1', letter: 'k'
# text: 'dwdddzd', min: '4', max: '5', letter: 'd'
# text: 'wwwwwwwxww', min: '7', max: '8', letter: 'w'
# 306
